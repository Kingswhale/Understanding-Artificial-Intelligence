# %%
conda update --all
# Out:
# Retrieving notices: ...working... DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): conda.anaconda.org:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/r/notices.json HTTP/1.1" 404 None
# DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /conda-forge/notices.json HTTP/1.1" 404 None
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/notices.json HTTP/1.1" 404 None
# done
# Collecting package metadata (current_repodata.json): \ DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): conda.anaconda.org:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): conda.anaconda.org:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# | DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/r/noarch/current_repodata.json HTTP/1.1" 304 0
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/r/osx-64/current_repodata.json HTTP/1.1" 304 0
# / DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/noarch/current_repodata.json HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /conda-forge/osx-64/current_repodata.json HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /conda-forge/noarch/current_repodata.json HTTP/1.1" 200 None
# \ DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/osx-64/current_repodata.json HTTP/1.1" 200 None
# / WARNING conda.models.version:get_matcher(556): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.7.1.*, but conda is ignoring the .* and treating it as 1.7.1
# done
# Solving environment: \
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/osx-64::hvplot==0.8.4=py311hecd8cb5_0
#   - defaults/osx-64::nbclassic==0.5.5=py311hecd8cb5_0
#   - defaults/osx-64::jupyter_server_fileid==0.9.0=py311hecd8cb5_0
#   - defaults/osx-64::typing-extensions==4.7.1=py311hecd8cb5_0
#   - defaults/osx-64::holoviews==1.17.0=py311hecd8cb5_0
#   - defaults/noarch::argon2-cffi==21.3.0=pyhd3eb1b0_0
#   - defaults/osx-64::scrapy==2.8.0=py311hecd8cb5_0
#   - defaults/osx-64::anaconda-navigator==2.4.2=py311hecd8cb5_0
#   - defaults/noarch::conda-content-trust==0.1.1=pyhd3eb1b0_0
#   - defaults/osx-64::jupyter==1.0.0=py311hecd8cb5_8
#   - defaults/osx-64::twisted==22.10.0=py311h6c40b1e_0
#   - defaults/osx-64::jupyterlab_server==2.22.0=py311hecd8cb5_0
#   - defaults/osx-64::panel==1.2.1=py311hecd8cb5_0
#   - defaults/osx-64::_anaconda_depends==2023.07=py311_1
#   - defaults/osx-64::notebook==6.5.4=py311hecd8cb5_1
#   - defaults/osx-64::jupyter_server_ydoc==0.8.0=py311hecd8cb5_1
#   - defaults/osx-64::s3fs==2023.3.0=py311hecd8cb5_0
#   - defaults/noarch::aioitertools==0.7.1=pyhd3eb1b0_0
#   - defaults/osx-64::aiobotocore==2.4.2=py311hecd8cb5_0
#   - defaults/osx-64::jupyterlab==3.6.3=py311hecd8cb5_0
#   - defaults/noarch::conda-token==0.4.0=pyhd3eb1b0_0
#   - defaults/osx-64::jupyter_server==1.23.4=py311hecd8cb5_0
#   - defaults/osx-64::notebook-shim==0.2.2=py311hecd8cb5_0
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local/anaconda3
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _anaconda_depends-2023.09  | py311_openblas_0          68 KB
#     aiohttp-3.8.5              |  py311h6c40b1e_0         554 KB
#     anaconda-anon-usage-0.4.0  |  py311hfb7c958_0          28 KB
#     anaconda-client-1.12.1     |  py311hecd8cb5_0         208 KB
#     blas-2.106                 |         openblas          12 KB  conda-forge
#     c-ares-1.19.1              |       h6c40b1e_0         107 KB
#     ca-certificates-2023.08.22 |       hecd8cb5_0         124 KB
#     conda-23.7.4               |  py311hecd8cb5_0         1.3 MB
#     conda-build-3.26.1         |  py311hecd8cb5_0         831 KB
#     conda-libmamba-solver-23.7.0|  py311hecd8cb5_0          88 KB
#     conda-repo-cli-1.0.75      |  py311hecd8cb5_0         182 KB
#     cryptography-38.0.4        |  py311h8661239_0         1.1 MB  conda-forge
#     curl-8.2.1                 |       hdb2fb19_0          78 KB
#     cyrus-sasl-2.1.28          |       h9b9944d_1         224 KB
#     dask-2022.2.1              |     pyhd3eb1b0_0           5 KB
#     dask-core-2022.2.1         |     pyhd3eb1b0_0         747 KB
#     datashader-0.15.2          |  py311hecd8cb5_0        17.0 MB
#     dill-0.3.7                 |  py311hecd8cb5_0         236 KB
#     distributed-2022.2.1       |     pyhd3eb1b0_0         659 KB
#     h5py-3.9.0                 |  py311hdb7e403_0         1.1 MB
#     hdf5-1.12.1                |       h2b2ad87_2         4.1 MB
#     ipykernel-6.25.0           |  py311h85bffb1_0         304 KB
#     ipython-8.15.0             |  py311hecd8cb5_0         1.4 MB
#     kaleido-core-0.2.1         |       hb664fd8_0        65.5 MB
#     libblas-3.9.0              |       6_openblas          11 KB  conda-forge
#     libcblas-3.9.0             |       6_openblas          11 KB  conda-forge
#     libclang-14.0.6            |default_hd95374b_1         138 KB
#     libclang13-14.0.6          |default_habbcc1a_1         7.1 MB
#     libcurl-8.2.1              |       ha585b31_0         360 KB
#     liblapack-3.9.0            |       6_openblas          11 KB  conda-forge
#     liblapacke-3.9.0           |       6_openblas          11 KB  conda-forge
#     libmamba-1.5.1             |       h812d603_0         1.4 MB
#     libmambapy-1.5.1           |  py311h06b2410_0         278 KB
#     libopenblas-0.3.12         |openmp_h54245bb_1         8.8 MB  conda-forge
#     libsolv-0.7.24             |       hfff2838_0         440 KB
#     libtiff-4.5.1              |       hcec6c5f_0         508 KB
#     libxml2-2.10.4             |       h930c0e2_0         666 KB
#     mathjax-2.7.5              |       hecd8cb5_0        17.4 MB
#     matplotlib-3.7.2           |  py311hecd8cb5_0           9 KB
#     matplotlib-base-3.7.2      |  py311h8251f7d_0         7.6 MB
#     mysql-5.7.24               |       h28d6cec_2        58.4 MB
#     nbformat-5.9.2             |  py311hecd8cb5_0         162 KB
#     numexpr-2.8.4              |  py311hd84f3f5_0         145 KB  conda-forge
#     numpy-1.23.5               |  py311h62c7003_0         6.3 MB  conda-forge
#     openssl-1.1.1w             |       hca72f7f_0         2.8 MB
#     packaging-23.1             |  py311hecd8cb5_0         101 KB
#     pandas-2.0.3               |  py311hdb55bb0_0        14.1 MB
#     partd-1.4.0                |  py311hecd8cb5_0          48 KB
#     pcre2-10.42                |       h9b97e30_0         1.3 MB
#     platformdirs-3.10.0        |  py311hecd8cb5_0          38 KB
#     pytables-3.8.0             |  py311h0b11676_3         2.3 MB
#     python-3.11.5              |       h1fd4e5f_0        15.6 MB
#     python-kaleido-0.2.1       |  py311hecd8cb5_0          29 KB
#     python-tzdata-2023.3       |     pyhd3eb1b0_0         140 KB
#     python_abi-3.11            |          2_cp311           5 KB  conda-forge
#     qt-main-5.15.2             |       h51e0635_9        45.0 MB
#     qt-webengine-5.15.9        |       h90a370e_7        52.0 MB
#     scipy-1.10.1               |  py311h939689b_0        22.4 MB  conda-forge
#     spyder-kernels-2.4.4       |  py311hecd8cb5_0         207 KB
#     ------------------------------------------------------------
#                                            Total:       361.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   anaconda-anon-usa~ pkgs/main/osx-64::anaconda-anon-usage-0.4.0-py311hfb7c958_0
#   cyrus-sasl         pkgs/main/osx-64::cyrus-sasl-2.1.28-h9b9944d_1
#   kaleido-core       pkgs/main/osx-64::kaleido-core-0.2.1-hb664fd8_0
#   libblas            conda-forge/osx-64::libblas-3.9.0-6_openblas
#   libcblas           conda-forge/osx-64::libcblas-3.9.0-6_openblas
#   libclang13         pkgs/main/osx-64::libclang13-14.0.6-default_habbcc1a_1
#   liblapack          conda-forge/osx-64::liblapack-3.9.0-6_openblas
#   liblapacke         conda-forge/osx-64::liblapacke-3.9.0-6_openblas
#   mathjax            pkgs/main/osx-64::mathjax-2.7.5-hecd8cb5_0
#   mysql              pkgs/main/osx-64::mysql-5.7.24-h28d6cec_2
#   python-kaleido     pkgs/main/osx-64::python-kaleido-0.2.1-py311hecd8cb5_0
#   python-tzdata      pkgs/main/noarch::python-tzdata-2023.3-pyhd3eb1b0_0
#   python_abi         conda-forge/osx-64::python_abi-3.11-2_cp311
#   typing_extensions  pkgs/main/osx-64::typing_extensions-4.7.1-py311hecd8cb5_0
#
# The following packages will be UPDATED:
#
#   _anaconda_depends                         2023.07-py311_1 --> 2023.09-py311_openblas_0
#   aiohttp                             3.8.3-py311h6c40b1e_0 --> 3.8.5-py311h6c40b1e_0
#   anaconda-client                    1.12.0-py311hecd8cb5_0 --> 1.12.1-py311hecd8cb5_0
#   blas                         pkgs/main::blas-1.0-openblas --> conda-forge::blas-2.106-openblas
#   c-ares                                  1.19.0-h6c40b1e_0 --> 1.19.1-h6c40b1e_0
#   ca-certificates                     2023.05.30-hecd8cb5_0 --> 2023.08.22-hecd8cb5_0
#   conda                              23.7.2-py311hecd8cb5_0 --> 23.7.4-py311hecd8cb5_0
#   conda-build                        3.26.0-py311hecd8cb5_0 --> 3.26.1-py311hecd8cb5_0
#   conda-libmamba-so~                 23.5.0-py311hecd8cb5_0 --> 23.7.0-py311hecd8cb5_0
#   conda-repo-cli                     1.0.41-py311hecd8cb5_0 --> 1.0.75-py311hecd8cb5_0
#   curl                                     8.1.1-hdb2fb19_2 --> 8.2.1-hdb2fb19_0
#   datashader                         0.15.1-py311hecd8cb5_0 --> 0.15.2-py311hecd8cb5_0
#   dill                                0.3.6-py311hecd8cb5_0 --> 0.3.7-py311hecd8cb5_0
#   h5py                                3.7.0-py311h4bbaca6_0 --> 3.9.0-py311hdb7e403_0
#   hdf5                                    1.10.6-h10fe05b_1 --> 1.12.1-h2b2ad87_2
#   ipykernel                          6.19.2-py311h4975b63_0 --> 6.25.0-py311h85bffb1_0
#   ipython                            8.12.0-py311hecd8cb5_0 --> 8.15.0-py311hecd8cb5_0
#   libclang                        12.0.0-default_hbc2896b_2 --> 14.0.6-default_hd95374b_1
#   libcurl                                  8.1.1-ha585b31_2 --> 8.2.1-ha585b31_0
#   libmamba                                 1.4.1-ha357a0b_0 --> 1.5.1-h812d603_0
#   libmambapy                          1.4.1-py311ha357a0b_0 --> 1.5.1-py311h06b2410_0
#   libsolv                                 0.7.22-h8346a28_0 --> 0.7.24-hfff2838_0
#   libtiff                                  4.5.0-hcec6c5f_2 --> 4.5.1-hcec6c5f_0
#   libxml2                                 2.10.3-h930c0e2_0 --> 2.10.4-h930c0e2_0
#   matplotlib                          3.7.1-py311hecd8cb5_1 --> 3.7.2-py311hecd8cb5_0
#   matplotlib-base                     3.7.1-py311h11e8b89_1 --> 3.7.2-py311h8251f7d_0
#   nbformat                            5.7.0-py311hecd8cb5_0 --> 5.9.2-py311hecd8cb5_0
#   openssl                                 1.1.1v-hca72f7f_0 --> 1.1.1w-hca72f7f_0
#   packaging                            23.0-py311hecd8cb5_0 --> 23.1-py311hecd8cb5_0
#   pandas                              1.5.3-py311hc5848a5_0 --> 2.0.3-py311hdb55bb0_0
#   partd              pkgs/main/noarch::partd-1.2.0-pyhd3eb~ --> pkgs/main/osx-64::partd-1.4.0-py311hecd8cb5_0
#   pcre2                                    10.37-he7042d7_1 --> 10.42-h9b97e30_0
#   platformdirs                        2.5.2-py311hecd8cb5_0 --> 3.10.0-py311hecd8cb5_0
#   pytables                            3.8.0-py311hbdc8ef1_2 --> 3.8.0-py311h0b11676_3
#   python                                  3.11.4-h1fd4e5f_0 --> 3.11.5-h1fd4e5f_0
#   qt-main                                 5.15.2-h719ae48_7 --> 5.15.2-h51e0635_9
#   qt-webengine                            5.15.9-h90a370e_4 --> 5.15.9-h90a370e_7
#   spyder-kernels                      2.4.3-py311hecd8cb5_0 --> 2.4.4-py311hecd8cb5_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   cryptography       pkgs/main::cryptography-41.0.2-py311h~ --> conda-forge::cryptography-38.0.4-py311h8661239_0
#   dask               pkgs/main/osx-64::dask-2023.6.0-py311~ --> pkgs/main/noarch::dask-2022.2.1-pyhd3eb1b0_0
#   dask-core          pkgs/main/osx-64::dask-core-2023.6.0-~ --> pkgs/main/noarch::dask-core-2022.2.1-pyhd3eb1b0_0
#   distributed        pkgs/main/osx-64::distributed-2023.6.~ --> pkgs/main/noarch::distributed-2022.2.1-pyhd3eb1b0_0
#   libopenblas        pkgs/main::libopenblas-0.3.21-h54e7dc~ --> conda-forge::libopenblas-0.3.12-openmp_h54245bb_1
#   numexpr            pkgs/main::numexpr-2.8.4-py311hd0e4f0~ --> conda-forge::numexpr-2.8.4-py311hd84f3f5_0
#   numpy              pkgs/main::numpy-1.24.3-py311hd0e4f0d~ --> conda-forge::numpy-1.23.5-py311h62c7003_0
#   scipy              pkgs/main::scipy-1.10.1-py311h7695dc5~ --> conda-forge::scipy-1.10.1-py311h939689b_0
#
#
#
# Downloading and Extracting Packages
# dask-core-2022.2.1   | 747 KB    |                                       |   0%
# partd-1.4.0          | 48 KB     |                                       |   0%
#
# matplotlib-3.7.2     | 9 KB      |                                       |   0%
#
#
# qt-webengine-5.15.9  | 52.0 MB   |                                       |   0% DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
#
#
#
#
# cyrus-sasl-2.1.28    | 224 KB    |                                       |   0% DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
#
#
#
#
#
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# ca-certificates-2023 | 124 KB    |                                       |   0%
#
#
#
#
#
# ipykernel-6.25.0     | 304 KB    |                                       |   0% DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
#
#
#
#
#
#
#
# libtiff-4.5.1        | 508 KB    |                                       |   0%
#
#
#
#
#
#
#
# conda-repo-cli-1.0.7 | 182 KB    |                                       |   0% DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
#
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# platformdirs-3.10.0  | 38 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# python-tzdata-2023.3 | 140 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# libmamba-1.5.1       | 1.4 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# _anaconda_depends-20 | 68 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# blas-2.106           | 12 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.0.3         | 14.1 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-kaleido-0.2.1 | 29 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# c-ares-1.19.1        | 107 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcblas-3.9.0       | 11 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.2       | 45.0 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# conda-libmamba-solve | 88 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# anaconda-anon-usage- | 28 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/osx-64/partd-1.4.0-py311hecd8cb5_0.conda HTTP/1.1" 200 48993
#
# partd-1.4.0          | 48 KB     | ############3                         |  33% DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/osx-64/qt-webengine-5.15.9-h90a370e_7.conda HTTP/1.1" 200 54491025
#
#
#
# qt-webengine-5.15.9  | 52.0 MB   |                                       |   0%
# partd-1.4.0          | 48 KB     | ##################################### | 100%
#
#
# qt-webengine-5.15.9  | 52.0 MB   | 1                                     |   0% DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/osx-64/matplotlib-3.7.2-py311hecd8cb5_0.conda HTTP/1.1" 200 9081
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/osx-64/ca-certificates-2023.08.22-hecd8cb5_0.conda HTTP/1.1" 200 126476
#
#
# matplotlib-3.7.2     | 9 KB      | ##################################### | 100%
#
#
#
#
# ca-certificates-2023 | 124 KB    | ####7                                 |  13% DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/noarch/dask-core-2022.2.1-pyhd3eb1b0_0.conda HTTP/1.1" 200 764637
#
#
# matplotlib-3.7.2     | 9 KB      | ##################################### | 100% DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/osx-64/cyrus-sasl-2.1.28-h9b9944d_1.conda HTTP/1.1" 200 228886
#
#
#
#
# dask-core-2022.2.1   | 747 KB    | 7                                     |   2% DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/osx-64/ipykernel-6.25.0-py311h85bffb1_0.conda HTTP/1.1" 200 311340
# dask-core-2022.2.1   | 747 KB    | ##3                                   |   6%
#
#
# qt-webengine-5.15.9  | 52.0 MB   | 1                                     |   0%
#
#
#
# cyrus-sasl-2.1.28    | 224 KB    | ##########5                           |  29%
#
#
# dask-core-2022.2.1   | 747 KB    | ###9                                  |  11%
#
#
#
# cyrus-sasl-2.1.28    | 224 KB    | ###############8                      |  43%
#
#
#
#
#
# ipykernel-6.25.0     | 304 KB    | #9                                    |   5%
#
#
#
# cyrus-sasl-2.1.28    | 224 KB    | ##################################### | 100%
#
#
# dask-core-2022.2.1   | 747 KB    | #############4                        |  36%
#
#
#
#
#
# ipykernel-6.25.0     | 304 KB    | ###8                                  |  11%
#
#
# qt-webengine-5.15.9  | 52.0 MB   | 5                                     |   1% DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/osx-64/libtiff-4.5.1-hcec6c5f_0.conda HTTP/1.1" 200 520463
#
#
#
#
#
# ca-certificates-2023 | 124 KB    | ###################1                  |  52%
#
#
#
#
#
# dask-core-2022.2.1   | 747 KB    | ################6                     |  45%
#
#
#
#
#
#
# libtiff-4.5.1        | 508 KB    | #1                                    |   3%
#
#
#
#
#
# ipykernel-6.25.0     | 304 KB    | #################5                    |  47%
#
#
#
#
# ca-certificates-2023 | 124 KB    | #######################9              |  65%
#
#
#
#
#
# ipykernel-6.25.0     | 304 KB    | #####################4                |  58%
#
#
# qt-webengine-5.15.9  | 52.0 MB   | 6                                     |   2%
#
#
#
#
#
#
# dask-core-2022.2.1   | 747 KB    | ####################6                 |  56%
#
#
#
#
# ca-certificates-2023 | 124 KB    | ############################7         |  78%
#
#
#
#
# ca-certificates-2023 | 124 KB    | ##################################### | 100%
#
#
#
#
#
# ipykernel-6.25.0     | 304 KB    | ##################################### | 100%
#
#
#
#
#
# ipykernel-6.25.0     | 304 KB    | ##################################### | 100% DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/osx-64/hdf5-1.12.1-h2b2ad87_2.conda HTTP/1.1" 200 4256559
#
#
#
#
#
#
#
# dask-core-2022.2.1   | 747 KB    | ##########################1           |  71%
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    | 1                                     |   0% DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/osx-64/conda-repo-cli-1.0.75-py311hecd8cb5_0.conda HTTP/1.1" 200 186071
#
#
#
# qt-webengine-5.15.9  | 52.0 MB   | 6                                     |   2%
#
#
#
#
#
#
# dask-core-2022.2.1   | 747 KB    | ############################5         |  77%
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    | #4                                    |   4%
#
#
#
#
#
#
# libtiff-4.5.1        | 508 KB    | ###############1                      |  41%
# qt-webengine-5.15.9  | 52.0 MB   | 7                                     |   2%
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    | ##9                                   |   8%
#
#
#
#
#
#
# dask-core-2022.2.1   | 747 KB    | #################################2    |  90%
#
#
# qt-webengine-5.15.9  | 52.0 MB   | 8                                     |   2%
#
#
#
#
#
#
#
# conda-repo-cli-1.0.7 | 182 KB    | ###2                                  |   9%
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    | ###7                                  |  10%
#
#
#
#
#
#
# libtiff-4.5.1        | 508 KB    | ########################4             |  66%
#
#
#
#
#
#
# libtiff-4.5.1        | 508 KB    | ###############################4      |  85%
#
#
#
#
#
#
#
# conda-repo-cli-1.0.7 | 182 KB    | #############                         |  35%
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    | ####5                                 |  12%
#
#
#
#
#
#
# libtiff-4.5.1        | 508 KB    | ####################################1 |  98%
#
#
# qt-webengine-5.15.9  | 52.0 MB   | 8                                     |   2%
#
#
#
#
#
#
# libtiff-4.5.1        | 508 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    | #####2                                |  14%
#
#
#
#
#
#
#
# conda-repo-cli-1.0.7 | 182 KB    | ################2                     |  44%
#
#
# dask-core-2022.2.1   | 747 KB    | ###################################6  |  96% DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/osx-64/platformdirs-3.10.0-py311hecd8cb5_0.conda HTTP/1.1" 200 39347
#
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    | #######8                              |  21%
#
#
#
#
#
#
#
#
#
# platformdirs-3.10.0  | 38 KB     | ###############4                      |  42%
#
#
# dask-core-2022.2.1   | 747 KB    | ##################################### | 100% DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/noarch/python-tzdata-2023.3-pyhd3eb1b0_0.conda HTTP/1.1" 200 143832
#
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    | ########8                             |  24%
#
#
#
#
#
#
#
#
#
#
# python-tzdata-2023.3 | 140 KB    | ####2                                 |  11%
#
#
#
#
#
#
#
# conda-repo-cli-1.0.7 | 182 KB    | ##########################            |  70%
#
#
# qt-webengine-5.15.9  | 52.0 MB   | #1                                    |   3%
#
#
#
#
#
#
#
#
#
#
# python-tzdata-2023.3 | 140 KB    | ################8                     |  46%
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    | #########8                            |  27%
#
#
#
#
#
#
#
# conda-repo-cli-1.0.7 | 182 KB    | ###################################8  |  97%
#
#
# qt-webengine-5.15.9  | 52.0 MB   | #2                                    |   3%
#
#
#
#
#
#
#
#
#
#
# python-tzdata-2023.3 | 140 KB    | #############################5        |  80%
#
#
#
#
#
#
#
# conda-repo-cli-1.0.7 | 182 KB    | ##################################### | 100%
#
#
# qt-webengine-5.15.9  | 52.0 MB   | #2                                    |   3%
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    | ##########6                           |  29%
#
#
#
#
#
#
#
#
#
# platformdirs-3.10.0  | 38 KB     | ##############################8       |  83% DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/osx-64/libmamba-1.5.1-h812d603_0.conda HTTP/1.1" 200 1417472
#
#
#
#
#
#
#
#
#
#
# platformdirs-3.10.0  | 38 KB     | ##################################### | 100% DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/osx-64/mysql-5.7.24-h28d6cec_2.conda HTTP/1.1" 200 61225846
#
#
#
# qt-webengine-5.15.9  | 52.0 MB   | #3                                    |   4%
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    | ###########5                          |  31%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# libmamba-1.5.1       | 1.4 MB    | 4                                     |   1% DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/osx-64/_anaconda_depends-2023.09-py311_openblas_0.conda HTTP/1.1" 200 69191
#
#
#
#
#
#
#
#
#
#
#
# python-tzdata-2023.3 | 140 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    | ############2                         |  33%
#
#
# qt-webengine-5.15.9  | 52.0 MB   | #4                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
#
#
# _anaconda_depends-20 | 68 KB     | ########7                             |  24%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# libmamba-1.5.1       | 1.4 MB    | #2                                    |   3% DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): conda.anaconda.org:443
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# _anaconda_depends-20 | 68 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# _anaconda_depends-20 | 68 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    | ############9                         |  35%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   |                                       |   0%
#
#
# qt-webengine-5.15.9  | 52.0 MB   | #4                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
# libmamba-1.5.1       | 1.4 MB    | ##1                                   |   6%
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    | #############6                        |  37%
#
#
# qt-webengine-5.15.9  | 52.0 MB   | #5                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   |                                       |   0%
#
#
# qt-webengine-5.15.9  | 52.0 MB   | #5                                    |   4%
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    | ##############3                       |  39% DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /conda-forge/osx-64/blas-2.106-openblas.tar.bz2 HTTP/1.1" 200 11918
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# blas-2.106           | 12 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# libmamba-1.5.1       | 1.4 MB    | ##9                                   |   8%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | 1                                     |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# blas-2.106           | 12 KB     | ##################################### | 100%
#
#
# qt-webengine-5.15.9  | 52.0 MB   | #5                                    |   4% DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/osx-64/pandas-2.0.3-py311hdb55bb0_0.conda HTTP/1.1" 200 14827931
#
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    | ###############                       |  41%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | 1                                     |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.0.3         | 14.1 MB   |                                       |   0%
# libmamba-1.5.1       | 1.4 MB    | ###8                                  |  10%
#
#
# qt-webengine-5.15.9  | 52.0 MB   | #6                                    |   4%
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    | ###############6                      |  42%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | 1                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.0.3         | 14.1 MB   | 1                                     |   0%
#
#
#
#
#
#
#
#
#
#
#
# libmamba-1.5.1       | 1.4 MB    | ####7                                 |  13%
#
#
# qt-webengine-5.15.9  | 52.0 MB   | #6                                    |   5%
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    | ################2                     |  44%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.0.3         | 14.1 MB   | 2                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | 2                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
# libmamba-1.5.1       | 1.4 MB    | #####5                                |  15%
#
#
# qt-webengine-5.15.9  | 52.0 MB   | #7                                    |   5%
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    | ################8                     |  45%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | 2                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.0.3         | 14.1 MB   | 3                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
# libmamba-1.5.1       | 1.4 MB    | ######4                               |  17%
#
#
# qt-webengine-5.15.9  | 52.0 MB   | #7                                    |   5%
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    | #################3                    |  47%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.0.3         | 14.1 MB   | 4                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | 2                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.0.3         | 14.1 MB   | 5                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
# libmamba-1.5.1       | 1.4 MB    | #######2                              |  20%
#
#
# qt-webengine-5.15.9  | 52.0 MB   | #8                                    |   5%
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    | #################9                    |  48%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | 3                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.0.3         | 14.1 MB   | 6                                     |   2%
#
#
# qt-webengine-5.15.9  | 52.0 MB   | #8                                    |   5%
#
#
#
#
#
#
#
#
#
#
#
# libmamba-1.5.1       | 1.4 MB    | ########1                             |  22%
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    | ##################3                   |  50%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | 3                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.0.3         | 14.1 MB   | 6                                     |   2%
#
#
# qt-webengine-5.15.9  | 52.0 MB   | #9                                    |   5%
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    | ##################7                   |  51%
#
#
#
#
#
#
#
#
#
#
#
# libmamba-1.5.1       | 1.4 MB    | ########9                             |  24%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | 3                                     |   1%
#
#
# qt-webengine-5.15.9  | 52.0 MB   | #9                                    |   5%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.0.3         | 14.1 MB   | 8                                     |   2%
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    | ###################2                  |  52%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | 3                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
# libmamba-1.5.1       | 1.4 MB    | #########8                            |  27%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.0.3         | 14.1 MB   | 8                                     |   2%
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    | ###################6                  |  53%
#
#
# qt-webengine-5.15.9  | 52.0 MB   | #9                                    |   5%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | 4                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
# libmamba-1.5.1       | 1.4 MB    | ###########5                          |  31%
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    | ####################                  |  54%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.0.3         | 14.1 MB   | #                                     |   3%
#
#
# qt-webengine-5.15.9  | 52.0 MB   | ##                                    |   5%
#
#
#
#
#
#
#
#
#
#
#
# libmamba-1.5.1       | 1.4 MB    | ############4                         |  34%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | 4                                     |   1%
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    | ####################5                 |  55%
#
#
# qt-webengine-5.15.9  | 52.0 MB   | ##                                    |   6%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.0.3         | 14.1 MB   | #1                                    |   3%
#
#
#
#
#
#
#
#
#
#
#
# libmamba-1.5.1       | 1.4 MB    | #############6                        |  37%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.0.3         | 14.1 MB   | #2                                    |   3%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | 4                                     |   1%
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    | ####################9                 |  57%
#
#
# qt-webengine-5.15.9  | 52.0 MB   | ##                                    |   6%
#
#
#
#
#
#
#
#
#
#
#
# libmamba-1.5.1       | 1.4 MB    | ##############5                       |  39%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | 5                                     |   1%
#
#
# qt-webengine-5.15.9  | 52.0 MB   | ##1                                   |   6%
#
#
#
#
#
#
#
#
#
#
#
# libmamba-1.5.1       | 1.4 MB    | ###############3                      |  42%
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    | #####################3                |  58%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.0.3         | 14.1 MB   | #3                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | 5                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
# libmamba-1.5.1       | 1.4 MB    | ################2                     |  44%
# pandas-2.0.3         | 14.1 MB   | #3                                    |   4%
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    | #####################9                |  59%
#
#
#
#
#
#
#
#
#
#
#
# libmamba-1.5.1       | 1.4 MB    | #################1                    |  46%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.0.3         | 14.1 MB   | #5                                    |   4%
#
#
# qt-webengine-5.15.9  | 52.0 MB   | ##1                                   |   6%
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    | ######################3               |  60%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | 5                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
# libmamba-1.5.1       | 1.4 MB    | #################9                    |  49%
#
#
# qt-webengine-5.15.9  | 52.0 MB   | ##1                                   |   6%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.0.3         | 14.1 MB   | #5                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | 6                                     |   2%
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    | ######################7               |  62%
#
#
#
#
#
#
#
#
#
#
#
# libmamba-1.5.1       | 1.4 MB    | ###################2                  |  52%
#
#
# qt-webengine-5.15.9  | 52.0 MB   | ##2                                   |   6%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.0.3         | 14.1 MB   | #7                                    |   5%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | 6                                     |   2%
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    | #######################3              |  63%
#
#
#
#
#
#
#
#
#
#
#
# libmamba-1.5.1       | 1.4 MB    | ####################1                 |  54%
#
#
# qt-webengine-5.15.9  | 52.0 MB   | ##2                                   |   6%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | 6                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.0.3         | 14.1 MB   | #8                                    |   5%
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    | #######################7              |  64%
#
#
#
#
#
#
#
#
#
#
#
# libmamba-1.5.1       | 1.4 MB    | #####################3                |  58%
#
#
# qt-webengine-5.15.9  | 52.0 MB   | ##2                                   |   6%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.0.3         | 14.1 MB   | #9                                    |   5%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | 6                                     |   2%
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    | ########################2             |  65%
#
#
#
#
#
#
#
#
#
#
#
# libmamba-1.5.1       | 1.4 MB    | ######################6               |  61%
#
#
# qt-webengine-5.15.9  | 52.0 MB   | ##3                                   |   6%
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    | ########################6             |  67%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.0.3         | 14.1 MB   | ##                                    |   6%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | 7                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
# libmamba-1.5.1       | 1.4 MB    | #######################9              |  65%
#
#
# qt-webengine-5.15.9  | 52.0 MB   | ##3                                   |   6%
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    | #########################             |  68%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | 7                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.0.3         | 14.1 MB   | ##1                                   |   6%
#
#
#
#
#
#
#
#
#
#
#
# libmamba-1.5.1       | 1.4 MB    | #########################2            |  68%
#
#
# qt-webengine-5.15.9  | 52.0 MB   | ##3                                   |   6%
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    | #########################4            |  69%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | 7                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.0.3         | 14.1 MB   | ##2                                   |   6%
#
#
#
#
#
#
#
#
#
#
#
# libmamba-1.5.1       | 1.4 MB    | ##########################5           |  72%
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    | #########################9            |  70%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.0.3         | 14.1 MB   | ##4                                   |   7%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | 8                                     |   2%
#
#
# qt-webengine-5.15.9  | 52.0 MB   | ##4                                   |   7%
#
#
#
#
#
#
#
#
#
#
#
# libmamba-1.5.1       | 1.4 MB    | ###########################7          |  75%
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    | ##########################3           |  71%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.0.3         | 14.1 MB   | ##5                                   |   7%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | 8                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
# libmamba-1.5.1       | 1.4 MB    | #############################         |  79%
#
#
# qt-webengine-5.15.9  | 52.0 MB   | ##4                                   |   7%
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    | ##########################7           |  72%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.0.3         | 14.1 MB   | ##6                                   |   7%
#
#
#
#
#
#
#
#
#
#
#
# libmamba-1.5.1       | 1.4 MB    | ##############################3       |  82%
#
#
# qt-webengine-5.15.9  | 52.0 MB   | ##5                                   |   7%
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    | ###########################2          |  74%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | 8                                     |   2%
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    | ###########################6          |  75%
#
#
# qt-webengine-5.15.9  | 52.0 MB   | ##5                                   |   7%
#
#
#
#
#
#
#
#
#
#
#
# libmamba-1.5.1       | 1.4 MB    | ###############################6      |  86%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.0.3         | 14.1 MB   | ##7                                   |   8%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | 9                                     |   2%
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    | ############################          |  76%
#
#
#
#
#
#
#
#
#
#
#
# libmamba-1.5.1       | 1.4 MB    | ################################9     |  89%
#
#
# qt-webengine-5.15.9  | 52.0 MB   | ##5                                   |   7%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.0.3         | 14.1 MB   | ##9                                   |   8%
# mysql-5.7.24         | 58.4 MB   | 9                                     |   3%
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    | ############################4         |  77%
#
#
# qt-webengine-5.15.9  | 52.0 MB   | ##6                                   |   7%
#
#
#
#
#
#
#
#
#
#
#
# libmamba-1.5.1       | 1.4 MB    | ##################################2   |  92%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.0.3         | 14.1 MB   | ###                                   |   8%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | 9                                     |   3%
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    | ############################9         |  78%
#
#
# qt-webengine-5.15.9  | 52.0 MB   | ##6                                   |   7%
#
#
#
#
#
#
#
#
#
#
#
# libmamba-1.5.1       | 1.4 MB    | ###################################4  |  96%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.0.3         | 14.1 MB   | ###1                                  |   9%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | 9                                     |   3%
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    | #############################3        |  79%
#
#
# qt-webengine-5.15.9  | 52.0 MB   | ##6                                   |   7%
#
#
#
#
#
#
#
#
#
#
#
# libmamba-1.5.1       | 1.4 MB    | ####################################7 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.0.3         | 14.1 MB   | ###2                                  |   9%
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    | #############################7        |  80%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | #                                     |   3%
#
#
#
#
#
#
#
#
#
#
#
# libmamba-1.5.1       | 1.4 MB    | ##################################### | 100%
#
#
# qt-webengine-5.15.9  | 52.0 MB   | ##7                                   |   7%
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    | ##############################1       |  82%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.0.3         | 14.1 MB   | ###3                                  |   9%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | #                                     |   3%
#
#
# qt-webengine-5.15.9  | 52.0 MB   | ##7                                   |   7% DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/osx-64/python-kaleido-0.2.1-py311hecd8cb5_0.conda HTTP/1.1" 200 29887
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-kaleido-0.2.1 | 29 KB     | ####################2                 |  55%
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    | ##############################6       |  83%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-kaleido-0.2.1 | 29 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.0.3         | 14.1 MB   | ###5                                  |  10%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | #                                     |   3%
#
#
# qt-webengine-5.15.9  | 52.0 MB   | ##7                                   |   7%
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    | ###############################       |  84% DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/osx-64/c-ares-1.19.1-h6c40b1e_0.conda HTTP/1.1" 200 109642
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.0.3         | 14.1 MB   | ###6                                  |  10%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | #1                                    |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# c-ares-1.19.1        | 107 KB    | #####5                                |  15%
#
#
# qt-webengine-5.15.9  | 52.0 MB   | ##8                                   |   8%
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    | ###############################4      |  85%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | #1                                    |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.0.3         | 14.1 MB   | ###7                                  |  10%
#
#
# qt-webengine-5.15.9  | 52.0 MB   | ##8                                   |   8%
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    | ###############################9      |  86%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# c-ares-1.19.1        | 107 KB    | ######################1               |  60% DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): conda.anaconda.org:443
#
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    | ################################3     |  87%
#
#
# qt-webengine-5.15.9  | 52.0 MB   | ##8                                   |   8%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | #1                                    |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.0.3         | 14.1 MB   | ###8                                  |  10%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# c-ares-1.19.1        | 107 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# c-ares-1.19.1        | 107 KB    | ##################################### | 100%
#
#
# qt-webengine-5.15.9  | 52.0 MB   | ##9                                   |   8%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | #1                                    |   3%
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    | ################################8     |  89%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.0.3         | 14.1 MB   | ####                                  |  11%
#
#
# qt-webengine-5.15.9  | 52.0 MB   | ##9                                   |   8%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | #2                                    |   3%
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    | #################################4    |  90%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.0.3         | 14.1 MB   | ####1                                 |  11% DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /conda-forge/osx-64/libcblas-3.9.0-6_openblas.tar.bz2 HTTP/1.1" 200 11467
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcblas-3.9.0       | 11 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcblas-3.9.0       | 11 KB     | ##################################### | 100%
#
#
# qt-webengine-5.15.9  | 52.0 MB   | ##9                                   |   8%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | #2                                    |   3%
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    | ##################################    |  92%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.0.3         | 14.1 MB   | ####2                                 |  11%
#
#
# qt-webengine-5.15.9  | 52.0 MB   | ###                                   |   8% DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/osx-64/qt-main-5.15.2-h51e0635_9.conda HTTP/1.1" 200 47215647
# mysql-5.7.24         | 58.4 MB   | #2                                    |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.0.3         | 14.1 MB   | ####3                                 |  12%
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    | ##################################6   |  94%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.2       | 45.0 MB   |                                       |   0%
#
#
# qt-webengine-5.15.9  | 52.0 MB   | ###                                   |   8%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | #3                                    |   4%
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    | ###################################   |  95%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.0.3         | 14.1 MB   | ####4                                 |  12%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.2       | 45.0 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | #3                                    |   4%
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    | ###################################4  |  96%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.0.3         | 14.1 MB   | ####6                                 |  12%
#
#
# qt-webengine-5.15.9  | 52.0 MB   | ###                                   |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.2       | 45.0 MB   |                                       |   0%
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    | ###################################8  |  97%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | #3                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.0.3         | 14.1 MB   | ####7                                 |  13%
#
#
# qt-webengine-5.15.9  | 52.0 MB   | ###1                                  |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.2       | 45.0 MB   | 1                                     |   0%
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    | ####################################3 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | #4                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.2       | 45.0 MB   | 1                                     |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.0.3         | 14.1 MB   | ####8                                 |  13%
#
#
# qt-webengine-5.15.9  | 52.0 MB   | ###1                                  |   9%
#
#
#
#
#
#
#
#
# hdf5-1.12.1          | 4.1 MB    | ####################################7 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | #4                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.2       | 45.0 MB   | 1                                     |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.0.3         | 14.1 MB   | ####9                                 |  13%
#
#
# qt-webengine-5.15.9  | 52.0 MB   | ###1                                  |   9%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | #4                                    |   4%
#
#
#
#
#
#
#
#
# ...
# mysql-5.7.24         | 58.4 MB   | ################################3     |  87%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ################################3     |  88%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ################################4     |  88%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ################################4     |  88%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ################################4     |  88%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ################################5     |  88%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ################################5     |  88%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ################################5     |  88%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ################################6     |  88%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ################################6     |  88%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ################################6     |  88%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ################################6     |  88%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ################################7     |  88%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ################################7     |  89%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ################################8     |  89%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ################################8     |  89%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ################################8     |  89%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ################################8     |  89%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ################################9     |  89%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ################################9     |  89%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ################################9     |  89%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | #################################     |  89%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | #################################     |  89%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | #################################     |  89%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | #################################     |  89%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | #################################1    |  90%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | #################################1    |  90%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | #################################2    |  90%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | #################################2    |  90%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | #################################2    |  90%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | #################################3    |  90%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | #################################3    |  90%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | #################################3    |  90%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | #################################4    |  90%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | #################################4    |  90%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | #################################4    |  90%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | #################################5    |  91%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | #################################5    |  91%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | #################################5    |  91%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | #################################6    |  91%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | #################################6    |  91%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | #################################6    |  91%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | #################################6    |  91%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | #################################7    |  91%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | #################################7    |  91%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | #################################7    |  91%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | #################################8    |  91%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | #################################8    |  91%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | #################################8    |  92%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | #################################9    |  92%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | #################################9    |  92%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | #################################9    |  92%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | #################################9    |  92%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ##################################    |  92%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ##################################    |  92%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ##################################    |  92%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ##################################1   |  92%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ##################################1   |  92%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ##################################1   |  92%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ##################################1   |  92%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ##################################2   |  93%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ##################################2   |  93%
# mysql-5.7.24         | 58.4 MB   | ##################################2   |  93%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ##################################3   |  93%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ##################################3   |  93%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ##################################3   |  93%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ##################################4   |  93%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ##################################4   |  93%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ##################################4   |  93%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ##################################5   |  93%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ##################################5   |  93%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ##################################5   |  93%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ##################################6   |  94%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ##################################6   |  94%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ##################################6   |  94%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ##################################6   |  94%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ##################################7   |  94%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ##################################7   |  94%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ##################################7   |  94%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ##################################7   |  94%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ##################################8   |  94%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ##################################8   |  94%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ##################################8   |  94%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ##################################9   |  94%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ##################################9   |  94%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ##################################9   |  95%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ###################################   |  95%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ###################################   |  95%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ###################################   |  95%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ###################################   |  95%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ###################################1  |  95%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ###################################1  |  95%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ###################################1  |  95%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ###################################2  |  95%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ###################################2  |  95%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ###################################2  |  95%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ###################################3  |  95%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ###################################3  |  96%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ###################################3  |  96%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ###################################4  |  96%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ###################################4  |  96%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ###################################4  |  96%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ###################################5  |  96%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ###################################5  |  96%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ###################################6  |  96%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ###################################6  |  96%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ###################################6  |  96%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ###################################7  |  97%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ###################################7  |  97%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ###################################7  |  97%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ###################################8  |  97%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ###################################8  |  97%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ###################################9  |  97%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ###################################9  |  97%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ###################################9  |  97%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ####################################  |  97%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ####################################  |  97%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ####################################1 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ####################################1 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ####################################1 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ####################################2 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ####################################2 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ####################################3 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ####################################3 |  98%
# mysql-5.7.24         | 58.4 MB   | ####################################3 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ####################################4 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ####################################4 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ####################################5 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ####################################5 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ####################################5 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ####################################5 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ####################################6 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ####################################6 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ####################################7 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ####################################7 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ####################################7 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ####################################8 | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ####################################8 | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ####################################9 | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ####################################9 | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ####################################9 | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-5.7.24         | 58.4 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: - WARNING conda.core.path_actions:verify(1051): Unable to create environments file. Path not writable.
#   environment location: /Users/user/.conda/environments.txt
#
# done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Categorical Data Plots
#
# Now let's discuss using seaborn to plot categorical data! There are a few main plot types for this:
#
# * factorplot
# * boxplot
# * violinplot
# * stripplot
# * swarmplot
# * barplot
# * countplot
#
# Let's go through examples of each!

# %%
import seaborn as sns
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## barplot and countplot
#
# These very similar plots allow you to get aggregate data off a categorical feature in your data. **barplot** is a general plot that allows you to aggregate the categorical data based off some function, by default the mean:

# %%
sns.barplot(x='sex',y='total_bill',data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
import numpy as np

# %% [markdown]
# You can change the estimator object to your own function, that converts a vector to a scalar:

# %%
sns.barplot(x='sex',y='total_bill',data=tips,estimator=np.std)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# ### countplot
#
# This is essentially the same as barplot except the estimator is explicitly counting the number of occurrences. Which is why we only pass the x value:

# %%
sns.countplot(x='sex',data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# ## boxplot and violinplot
#
# boxplots and violinplots are used to shown the distribution of categorical data. A box plot (or box-and-whisker plot) shows the distribution of quantitative data in a way that facilitates comparisons between variables or across levels of a categorical variable. The box shows the quartiles of the dataset while the whiskers extend to show the rest of the distribution, except for points that are determined to be “outliers” using a method that is a function of the inter-quartile range.

# %%
sns.boxplot(x="day", y="total_bill", data=tips,palette='rainbow')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# Can do entire dataframe with orient='h'
sns.boxplot(data=tips,palette='rainbow',orient='h')
# Out:
# <Axes: >

# %%
sns.boxplot(x="day", y="total_bill", hue="smoker",data=tips, palette="coolwarm")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### violinplot
# A violin plot plays a similar role as a box and whisker plot. It shows the distribution of quantitative data across several levels of one (or more) categorical variables such that those distributions can be compared. Unlike a box plot, in which all of the plot components correspond to actual datapoints, the violin plot features a kernel density estimation of the underlying distribution.

# %%
sns.violinplot(x="day", y="total_bill", data=tips,palette='rainbow')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x="day", y="total_bill", data=tips,hue='sex',palette='Set1')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x="day", y="total_bill", data=tips,hue='sex',split=True,palette='Set1')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ## stripplot and swarmplot
# The stripplot will draw a scatterplot where one variable is categorical. A strip plot can be drawn on its own, but it is also a good complement to a box or violin plot in cases where you want to show all observations along with some representation of the underlying distribution.
#
# The swarmplot is similar to stripplot(), but the points are adjusted (only along the categorical axis) so that they don’t overlap. This gives a better representation of the distribution of values, although it does not scale as well to large numbers of observations (both in terms of the ability to show all the points and in terms of the computation needed to arrange them).

# %%
sns.stripplot(x="day", y="total_bill", data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x="day", y="total_bill", data=tips,jitter=True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x="day", y="total_bill", data=tips,jitter=True,hue='sex',palette='Set1')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x="day", y="total_bill", data=tips,jitter=True,hue='sex',palette='Set1',split=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 sns.stripplot(x="day", y="total_bill", data=tips,jitter=True,hue='sex',palette='Set1',split=True)
#
# File /usr/local/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:2537, in stripplot(data, x, y, hue, order, hue_order, jitter, dodge, orient, color, palette, size, edgecolor, linewidth, hue_norm, native_scale, formatter, legend, ax, **kwargs)
#    2529 size = kwargs.get("s", size)
#    2531 kwargs.update(dict(
#    2532     s=size ** 2,
#    2533     edgecolor=edgecolor,
#    2534     linewidth=linewidth)
#    2535 )
# -> 2537 p.plot_strips(
#    2538     jitter=jitter,
#    2539     dodge=dodge,
#    2540     color=color,
#    2541     edgecolor=edgecolor,
#    2542     plot_kws=kwargs,
#    2543 )
#    2545 # XXX this happens inside a plotting method in the distribution plots
#    2546 # but maybe it's better out here? Alternatively, we have an open issue
#    2547 # suggesting that _attach could add default axes labels, which seems smart.
#    2548 p._add_axis_labels(ax)
#
# File /usr/local/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:299, in _CategoricalPlotterNew.plot_strips(self, jitter, dodge, color, edgecolor, plot_kws)
#     296         sub_data[var] = np.power(10, sub_data[var])
#     298 ax = self._get_axes(sub_vars)
# --> 299 points = ax.scatter(sub_data["x"], sub_data["y"], color=color, **plot_kws)
#     301 if "hue" in self.variables:
#     302     points.set_facecolors(self._hue_map(sub_data["hue"]))
#
# File /usr/local/anaconda3/lib/python3.11/site-packages/matplotlib/__init__.py:1442, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1439 @functools.wraps(func)
#    1440 def inner(ax, *args, data=None, **kwargs):
#    1441     if data is None:
# -> 1442         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1444     bound = new_sig.bind(ax, *args, **kwargs)
#    1445     auto_label = (bound.arguments.get(label_namer)
#    1446                   or bound.kwargs.get(label_namer))
#
# File /usr/local/anaconda3/lib/python3.11/site-packages/matplotlib/axes/_axes.py:4698, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4694         keys_str = ", ".join(f"'{k}'" for k in extra_keys)
#    4695         _api.warn_external(
#    4696             "No data for colormapping provided via 'c'. "
#    4697             f"Parameters {keys_str} will be ignored")
# -> 4698 collection._internal_update(kwargs)
#    4700 # Classic mode only:
#    4701 # ensure there are margins to allow for the
#    4702 # finite size of the symbols.  In v2.x, margins
#    4703 # are present by default, so we disable this
#    4704 # scatter-specific override.
#    4705 if mpl.rcParams['_internal.classic_mode']:
#
# File /usr/local/anaconda3/lib/python3.11/site-packages/matplotlib/artist.py:1223, in Artist._internal_update(self, kwargs)
#    1216 def _internal_update(self, kwargs):
#    1217     """
#    1218     Update artist properties without prenormalizing them, but generating
#    1219     errors as if calling `set`.
#    1220
#    1221     The lack of prenormalization is to maintain backcompatibility.
#    1222     """
# -> 1223     return self._update_props(
#    1224         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1225         "{prop_name!r}")
#
# File /usr/local/anaconda3/lib/python3.11/site-packages/matplotlib/artist.py:1197, in Artist._update_props(self, props, errfmt)
#    1195             func = getattr(self, f"set_{k}", None)
#    1196             if not callable(func):
# -> 1197                 raise AttributeError(
#    1198                     errfmt.format(cls=type(self), prop_name=k))
#    1199             ret.append(func(v))
#    1200 if ret:
#
# AttributeError: PathCollection.set() got an unexpected keyword argument 'split'

# %%
sns.swarmplot(x="day", y="total_bill", data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x="day", y="total_bill",hue='sex',data=tips, palette="Set1")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### Combining Categorical Plots

# %%
sns.violinplot(x="tip", y="day", data=tips,palette='rainbow')
sns.swarmplot(x="tip", y="day", data=tips,color='black',size=3)
# Out:
# <Axes: xlabel='tip', ylabel='day'>

# %% [markdown]
# ## factorplot
#
# factorplot is the most general form of a categorical plot. It can take in a **kind** parameter to adjust the plot type:

# %%
sns.factorplot(x='sex',y='total_bill',data=tips,kind='bar')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 sns.factorplot(x='sex',y='total_bill',data=tips,kind='bar')
#
# AttributeError: module 'seaborn' has no attribute 'factorplot'

# %% [markdown]
# # Great Job!
